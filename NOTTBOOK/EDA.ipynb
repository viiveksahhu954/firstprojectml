# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\viive\OneDrive\Desktop/student-dataset.csv")

# %%
df.head(2)
# Out:
#    id            name               nationality           city  latitude  \
# 0   0       Kiana Lor                     China         Suzhou     31.31
# 1   1  Joshua Lonaker  United States of America  Santa Clarita     34.39
#
#    longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     120.62      F           NaN   22            3.5         3.7
# 1    -118.54      M           NaN   22            2.9         3.2
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# 0             3.1             1.0                 4                 4.0
# 1             3.6             5.0                 5                 4.0
#
#    refletter.rating
# 0                 4
# 1                 5

# %%
df.drop(columns=['id'])
# Out:
#                   name               nationality                 city  \
# 0            Kiana Lor                     China               Suzhou
# 1       Joshua Lonaker  United States of America        Santa Clarita
# 2        Dakota Blanco  United States of America              Oakland
# 3      Natasha Yarusso  United States of America        Castro Valley
# 4       Brooke Cazares                    Brazil  São José dos Campos
# ..                 ...                       ...                  ...
# 302        Austin Haas  United States of America             Columbus
# 303    Madison Fithian  United States of America          Los Angeles
# 304  Zachary Mulvahill  United States of America          Los Angeles
# 305   Eliana Michelsen  United States of America              Oakland
# 306    Dane Whittemore                    Canada              Toronto
#
#      latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  307 non-null    int64
#  1   name                307 non-null    str
#  2   nationality         307 non-null    str
#  3   city                307 non-null    str
#  4   latitude            307 non-null    float64
#  5   longitude           307 non-null    float64
#  6   gender              307 non-null    str
#  7   ethnic.group        0 non-null      float64
#  8   age                 307 non-null    int64
#  9   english.grade       307 non-null    float64
#  10  math.grade          307 non-null    float64
#  11  sciences.grade      307 non-null    float64
#  12  language.grade      307 non-null    float64
#  13  portfolio.rating    307 non-null    int64
#  14  coverletter.rating  307 non-null    float64
#  15  refletter.rating    307 non-null    int64
# ...

# %%
df.drop(columns=["ethnic.group"])
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
#      latitude  longitude gender  age  english.grade  math.grade  \
# ...

# %%
df.isnull().sum()
# Out:
# id                      0
# name                    0
# nationality             0
# city                    0
# latitude                0
# longitude               0
# gender                  0
# ethnic.group          307
# age                     0
# english.grade           0
# math.grade              0
# sciences.grade          0
# language.grade          0
# portfolio.rating        0
# coverletter.rating      0
# refletter.rating        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 302    False
# 303    False
# 304    False
# 305    False
# 306    False
# Length: 307, dtype: bool

# %%
df.shape
# Out:
# (307, 16)

# %%
numeric_fea=[feature for feature in df.columns if df[feature].dtype !='0']
cate_fea=[feature for feature in df.columns if df[feature].dtype =='0']

print('we have{}numefeature ric feat:{}'.format(len(numeric_fea),numeric_fea))
print('/nwe have{}cat fe ric feat:{}'.format(len(cate_fea),cate_fea))
# Out:
# we have16numefeature ric feat:['id', 'name', 'nationality', 'city', 'latitude', 'longitude', 'gender', 'ethnic.group', 'age', 'english.grade', 'math.grade', 'sciences.grade', 'language.grade', 'portfolio.rating', 'coverletter.rating', 'refletter.rating']
# /nwe have0cat fe ric feat:[]
